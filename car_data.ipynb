# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car = pd.read_csv('car data.csv')
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
car.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
car.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
car.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
### missing values
missing_values = car.isnull().sum()
missing_values
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
continuous_data = car.select_dtypes(exclude='object')
continuous_data
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner
# 0    2014           3.35           5.59       27000      0
# 1    2013           4.75           9.54       43000      0
# 2    2017           7.25           9.85        6900      0
# 3    2011           2.85           4.15        5200      0
# 4    2014           4.60           6.87       42450      0
# ..    ...            ...            ...         ...    ...
# 296  2016           9.50          11.60       33988      0
# 297  2015           4.00           5.90       60000      0
# 298  2009           3.35          11.00       87934      0
# 299  2017          11.50          12.50        9000      0
# 300  2016           5.30           5.90        5464      0
#
# [301 rows x 5 columns]

# %%
categorical_data = car.select_dtypes(include='object')
categorical_data
# Out:
#     Car_Name Fuel_Type Seller_Type Transmission
# 0       ritz    Petrol      Dealer       Manual
# 1        sx4    Diesel      Dealer       Manual
# 2       ciaz    Petrol      Dealer       Manual
# 3    wagon r    Petrol      Dealer       Manual
# 4      swift    Diesel      Dealer       Manual
# ..       ...       ...         ...          ...
# 296     city    Diesel      Dealer       Manual
# 297     brio    Petrol      Dealer       Manual
# 298     city    Petrol      Dealer       Manual
# 299     city    Diesel      Dealer       Manual
# 300     brio    Petrol      Dealer       Manual
#
# [301 rows x 4 columns]

# %%
#checking for number of Transmission

car['Transmission'].value_counts()
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %%
car['Transmission'].nunique()
# Out:
# 2

# %%
#checking for number of Fuel_Type
car['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
car['Fuel_Type'].nunique()
# Out:
# 3

# %%
#checking for number of Car_Name
car['Car_Name'].value_counts()
# Out:
# Car_Name
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: count, Length: 98, dtype: int64

# %%
car['Car_Name'].nunique()
# Out:
# 98

# %% [markdown]
# ### Data cleaning

# %%
## checking for duplicates
car.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# Length: 301, dtype: bool

# %%
duplicate_rows = car[car.duplicated()]
duplicate_rows
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 17    ertiga  2016           7.75          10.79       43000    Diesel
# 93  fortuner  2015          23.00          30.61       40000    Diesel
#
#    Seller_Type Transmission  Owner
# 17      Dealer       Manual      0
# 93      Dealer    Automatic      0

# %%
# Check for duplicates based on specific columns
duplicates_subset = car.duplicated(subset=['Car_Name', 'Year'])
duplicates_subset
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 296     True
# 297     True
# 298     True
# 299    False
# 300     True
# Length: 301, dtype: bool

# %%
# Show only duplicate rows based on specific columns
duplicate_rows_subset = car[car.duplicated(subset=['Car_Name', 'Year'])]

# %%
# Remove duplicate rows based on specific columns   
car_cleaned = car.drop_duplicates(subset=['Car_Name', 'Year'])
car_cleaned
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 274     brio  2014           5.30           6.80       16500    Petrol
# 281     city  2006           2.10           7.60       50456    Petrol
# 284     brio  2013           3.50           5.90        9800    Petrol
# 293     city  2010           3.25           9.90       38000    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
car_cleaned1 = car.drop_duplicates()
car_cleaned1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
car_cleaned1.dropna()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
car_cleaned1.dropna(subset=['Car_Name', 'Year'])
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
car.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# ...

# %% [markdown]
# #### checking for outliers

# %%
def boxplot_outliers(car):
    for i in car.columns:
        plt.boxplot(car[i])
        plt.title(i)
        plt.show(i)

# %%
boxplot_outliers(continuous_data)

# %% [markdown]
# ### Data cleaning using IQR

# %%
def removing_outliers(car):
    for i in car.columns:
        
        q1 = car[i].quantile(0.25)
        q3 = car[i].quantile(0.75)
        iqr = q3 - q1
        lower_limit = q1 - 1.5*iqr
        upper_limit = q3 + 1.5*iqr
        car[i] = np.where(car[i]>upper_limit,upper_limit,car[i])
        car[i] = np.where(car[i]<lower_limit,lower_limit,car[i])

# %%
removing_outliers(continuous_data)

# %%
boxplot_outliers(continuous_data)
